# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
train = pd.read_csv('/kaggle/input/bike-sharing-demand/train.csv')
train.head(30)

# %%
train['datetime']=train['datetime'].astype('datetime64')
train.dtypes
train['datetime'].dt.hour
train['hour'] = train['datetime'].dt.hour
train['year'] = train['datetime'].dt.year
train['dayofweek'] =train['datetime'].dt.weekday
train['day'] = train['datetime'].dt.day
train.head()

# %%
train.groupby('year')['count'].mean()
train.groupby('year')['count'].median()
train.groupby('dayofweek')['count'].mean()
train['dayofweek'].value_counts()
train['day'].unique()

# %%
test = pd.read_csv('/kaggle/input/bike-sharing-demand/test.csv')
test.head()

# %%
test['datetime']=test['datetime'].astype('datetime64')
test.dtypes
test['datetime'].dt.hour
test['hour'] = test['datetime'].dt.hour
test['year'] = test['datetime'].dt.year
test['day of week'] = test['datetime'].dt.weekday
test['day'] = test['datetime'].dt.day
test['day'].unique()

# %%
train.drop(['datetime','casual','registered','count'],axis=1)

# %%
train.head()

# %%
train2 = train.drop(['datetime','casual','registered','count'],axis=1)

# %%
train2.head()

# %%
test2 = test.drop(['datetime'],axis=1)

# %%
test2.head()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100,n_jobs=4,random_state=33)

# %%
rf.fit(train2,train['count'])

# %%
result  = rf.predict(test2)

# %%
test['count'] = result
test.head(30)

# %%
sub = pd.read_csv('/kaggle/input/bike-sharing-demand/sampleSubmission.csv')

# %%
sub.head()

# %%
result

# %%
sub['count'] = result
sub.head()

# %%
sub.to_csv('firstclass.csv',index=False)
